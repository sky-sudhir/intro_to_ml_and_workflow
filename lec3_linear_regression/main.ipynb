# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('housing.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
mean_df=df.describe()
mean_df
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
sorted_df=df.sort_values(by='median_house_value',ascending=False)
sorted_df.tail(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2779     -114.65     32.79                21.0         44.0            33.0
# 1825     -122.32     37.93                33.0        296.0            73.0
# 13889    -116.57     35.43                 8.0       9975.0          1743.0
# 14326    -117.16     32.71                52.0        845.0           451.0
# 16186    -121.29     37.95                52.0        107.0            79.0
# 5887     -118.33     34.15                39.0        493.0           168.0
# 9188     -117.86     34.24                52.0        803.0           267.0
# 19802    -123.17     40.31                36.0         98.0            28.0
# 2799     -117.02     36.40                19.0        619.0           239.0
# 2521     -122.74     39.71                16.0        255.0            73.0
#
#        population  households  median_income  median_house_value  \
# 2779         64.0        27.0         0.8571             25000.0
# ...

# %%
corr_df=df.corr(numeric_only=True)
corr_df
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# ...

# %%
sns.heatmap(corr_df,annot=True,cmap='coolwarm')
plt.show()

# %%
# Generate scatter plots for key feature relationships

sns.pairplot(df, vars=['median_income', 'total_rooms', 'housing_median_age', 'median_house_value'])
plt.show()

# %%
describe_bedrooms=df['total_bedrooms'].describe()
describe_bedrooms
# Out:
# count    20433.000000
# mean       537.870553
# std        421.385070
# min          1.000000
# 25%        296.000000
# 50%        435.000000
# 75%        647.000000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
df_not_null=df[df['total_bedrooms'].notnull()]

df["room_bed_ratio"]=df["total_rooms"]/df["total_bedrooms"]
print(df["room_bed_ratio"].describe())
df.head()
# Out:
# count    20433.000000
# mean         4.984829
# std          1.171676
# min          1.000000
# 25%          4.169782
# 50%          4.922170
# 75%          5.700364
# max         10.000000
# Name: room_bed_ratio, dtype: float64
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# ...

# %%
mean_of_ratio=df["room_bed_ratio"].mean()
df["imputed_bedroom"]=df["total_bedrooms"]

df["imputed_bedroom"] = df["imputed_bedroom"].fillna(df["total_rooms"]/mean_of_ratio)

df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# room_bed_ratio        207
# imputed_bedroom         0
# dtype: int64

# %%
df_ocean=df[["median_house_value","ocean_proximity"]].groupby("ocean_proximity").mean().reset_index().plot.bar(x="ocean_proximity",y="median_house_value")

# %%
df_ocean=df[["total_rooms","ocean_proximity"]].groupby("ocean_proximity").mean().reset_index().plot.bar(x="ocean_proximity",y="total_rooms")

# %%
def get_island_values(val):
    if val=='ISLAND':
        return 1
    else:
        return 0

df["island"] = df["ocean_proximity"].apply(get_island_values)

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df_ocean=df[["housing_median_age","median_house_value"]].groupby("housing_median_age").mean().reset_index()
plt.scatter(df_ocean["housing_median_age"],df_ocean["median_house_value"])
plt.xlabel("housing_median_age")
# Out:
# Text(0.5, 0, 'housing_median_age')

# %%
df_ocean=df[["housing_median_age","total_rooms"]].groupby("housing_median_age").mean().reset_index()
plt.scatter(df_ocean["housing_median_age"],df_ocean["total_rooms"])
plt.xlabel("housing_median_age")
# Out:
# Text(0.5, 0, 'housing_median_age')

# %%
df[["housing_median_age","total_rooms","median_house_value"]].corr()
# Out:
#                     housing_median_age  total_rooms  median_house_value
# housing_median_age            1.000000    -0.361262            0.105623
# total_rooms                  -0.361262     1.000000            0.134153
# median_house_value            0.105623     0.134153            1.000000

# %%
df["latitude_longitude"]=df["latitude"]*df["longitude"]

df[["latitude_longitude","total_rooms","median_house_value"]].corr()
# Out:
#                     latitude_longitude  total_rooms  median_house_value
# latitude_longitude            1.000000     0.038303            0.104524
# total_rooms                   0.038303     1.000000            0.134153
# median_house_value            0.104524     0.134153            1.000000

# %%
df["population_per_household"]=df["population"]/df["households"]
df[["population_per_household","total_rooms","median_house_value","population"]].corr()
# Out:
#                           population_per_household  total_rooms  \
# population_per_household                  1.000000    -0.024581
# total_rooms                              -0.024581     1.000000
# median_house_value                       -0.023737     0.134153
# population                                0.069863     0.857126
#
#                           median_house_value  population
# population_per_household           -0.023737    0.069863
# total_rooms                         0.134153    0.857126
# median_house_value                  1.000000   -0.024650
# population                         -0.024650    1.000000

# %%
spearman_corr = df.corr(numeric_only=True,method='spearman')

# increase the size of the heatmap
plt.figure(figsize=(10,8))
sns.heatmap(spearman_corr,annot=True,cmap='coolwarm')
plt.show()

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    room_bed_ratio  imputed_bedroom  island  latitude_longitude  \
# ...

# %%
# change in one hot encoding for ocean_proximity with 0 and 1 values

ocean_proximity_dummies = pd.get_dummies(df['ocean_proximity'], prefix='ocean', drop_first=True).astype(int)
df = pd.concat([df, ocean_proximity_dummies], axis=1)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    room_bed_ratio  imputed_bedroom  island  latitude_longitude  \
# ...

# %%
# drop total_bedrooms ocean_proximity room_bed_ratio island columns
df=df.drop(columns=['total_bedrooms','ocean_proximity','room_bed_ratio','island'])
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  population  \
# 0    -122.23     37.88                41.0        880.0       322.0
# 1    -122.22     37.86                21.0       7099.0      2401.0
# 2    -122.24     37.85                52.0       1467.0       496.0
# 3    -122.25     37.85                52.0       1274.0       558.0
# 4    -122.25     37.85                52.0       1627.0       565.0
#
#    households  median_income  median_house_value  imputed_bedroom  \
# 0       126.0         8.3252            452600.0            129.0
# 1      1138.0         8.3014            358500.0           1106.0
# 2       177.0         7.2574            352100.0            190.0
# 3       219.0         5.6431            341300.0            235.0
# 4       259.0         3.8462            342200.0            280.0
#
#    latitude_longitude  population_per_household  ocean_INLAND  ocean_ISLAND  \
# 0          -4630.0724                  2.555556             0             0
# ...

# %%
# min max scaling
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df[df.columns] = scaler.fit_transform(df[df.columns])
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  population  \
# 0   0.211155  0.567481            0.784314     0.022331    0.008941
# 1   0.212151  0.565356            0.392157     0.180503    0.067210
# 2   0.210159  0.564293            1.000000     0.037260    0.013818
# 3   0.209163  0.564293            1.000000     0.032352    0.015555
# 4   0.209163  0.564293            1.000000     0.041330    0.015752
#
#    households  median_income  median_house_value  imputed_bedroom  \
# 0    0.020556       0.539668            0.902266         0.019863
# 1    0.186976       0.538027            0.708247         0.171477
# 2    0.028943       0.466028            0.695051         0.029330
# 3    0.035849       0.354699            0.672783         0.036313
# 4    0.042427       0.230776            0.674638         0.043296
#
#    latitude_longitude  population_per_household  ocean_INLAND  ocean_ISLAND  \
# 0            0.397330                  0.001499           0.0           0.0
# ...

# %%
spearman_corr2 = df.corr(numeric_only=True,method='spearman')

# increase the size of the heatmap
plt.figure(figsize=(10,8))
sns.heatmap(spearman_corr2,annot=True,cmap='coolwarm')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error,root_mean_squared_error
X=df.drop(columns=['median_house_value'])
y=df['median_house_value']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-2.45712905e+00,  5.85616008e+00,  1.07419531e-01, -3.43959132e-01,
#        -3.35450595e+00,  9.34103352e-01,  1.14034768e+00,  1.14391648e+00,
#         8.06830156e+00,  3.62057145e-01, -9.60178568e-02,  3.11928958e-01,
#        -4.50708242e-03,  2.04463777e-02])

# %%
lr.intercept_
# Out:
# np.float64(-5.905306383590976)

# %%
y_pred=lr.predict(X_test)
y_pred
# Out:
# array([0.26802543, 0.57334134, 0.32056463, ..., 0.30694181, 0.55760653,
#        0.2299593 ], shape=(4128,))

# %%
lr_r2score=r2_score(y_test,y_pred)
lr_mae=mean_absolute_error(y_test,y_pred)
lr_rmse=root_mean_squared_error(y_test,y_pred)
lr_mse=mean_squared_error(y_test,y_pred)

# %%
# Compare with a Ridge regression model (alpha=1.0)
from sklearn.linear_model import Ridge
ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train, y_train)
y_ridge_pred = ridge_model.predict(X_test)

# %%
ridge_model.coef_
# Out:
# array([-0.62684946, -0.18551066,  0.11286467, -0.34974638, -2.27618094,
#         0.50885661,  1.14437088,  1.0810871 ,  0.3724266 ,  0.00375991,
#        -0.08480463,  0.24985117, -0.00626389,  0.0101699 ])

# %%
ridge_model.intercept_
# Out:
# np.float64(0.19423740104298529)

# %%
ridge_mse=mean_squared_error(y_test,y_ridge_pred)
ridge_r2_score=r2_score(y_test,y_ridge_pred)
ridge_mae=mean_absolute_error(y_test,y_ridge_pred)
ridge_rmse=root_mean_squared_error(y_test,y_ridge_pred)

# %%
print("================= Linear Regression Metrics vs Ridge Regression Metrics (alpha=1.0) ================ ")
print(lr_r2score, ridge_r2_score)
print(lr_mae, ridge_mae)
print(lr_rmse, ridge_rmse)
print(lr_mse, ridge_mse)
# Out:
# ================= Linear Regression Metrics vs Ridge Regression Metrics (alpha=1.0) ================
# 0.6394998958469151 0.6442860464856401
# 0.10391312905763508 0.1043578728095326
# 0.14621326646614996 0.14523942906125623
# 0.021378319290701376 0.021094491754039678
